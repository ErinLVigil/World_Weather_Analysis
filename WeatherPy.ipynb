# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create as et of random latitute and longitude combinations. 

lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)

lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.

cities = []

#Identify the nearest city for each latitude and lognitude combination. 

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
#Print the city count to fonfirm sufficient count.

len(cities)
# Out:
# 602

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url= url + "&q=" + city

# %%
city_weather = requests.get(city_url)

# %%
# Imort the time library and teh datetime module from the datetime library

import time

from datetime import datetime

# %%
#Create an empty list to hold the weather data

city_data = []

#Print the beggining of the logging.

print("Beginning Data Retrieval    ")

print("----------------------------")


#Create counters.

record_count = 1

set_count = 1

#Loop through all the cities in our list.

for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        time.sleep(60)
        
        #Creae endpoint URL with each city.
        
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city.
    
    print(F"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    
    record_count += 1
    
#Run an AP request for each of the cities.
    try:
        #Parse teh JSON and retrieve the data.
        
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        #Conver the date to ISO standard.
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #Append the city information into a city_data list.
        
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng" : city_lng,
                         "Max Temp" : city_max_temp,
                         "Humidity" : city_humidity,
                         "Cloudiness" : city_clouds,
                         "Wind Speed": city_wind,
                         "Country" : city_country,
                         "Date" : city_date})
        
#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping ...")
        pass
    
#Indicate that Data Loading is complete.

print("------------------------------")

print("Data Retrieval Complete       ")

print("------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | salinas
# Processing Record 2 of Set 1 | taolanaro
# CIty not found. Skipping ...
# Processing Record 3 of Set 1 | russkaya polyana
# Processing Record 4 of Set 1 | port lincoln
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | kargopol
# Processing Record 8 of Set 1 | el badari
# CIty not found. Skipping ...
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | amderma
# CIty not found. Skipping ...
# Processing Record 11 of Set 1 | acari
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | staroaleyskoye
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | nishihara
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | dzhebariki-khaya
# Processing Record 21 of Set 1 | formoso do araguaia
# CIty not found. Skipping ...
# Processing Record 22 of Set 1 | townsville
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | faanui
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | haukipudas
# Processing Record 27 of Set 1 | belen
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | asfi
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | avera
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | kampene
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | korla
# Processing Record 38 of Set 1 | pisz
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | san luis de palenque
# Processing Record 41 of Set 1 | tari
# Processing Record 42 of Set 1 | mazatlan
# Processing Record 43 of Set 1 | sentyabrskiy
# CIty not found. Skipping ...
# Processing Record 44 of Set 1 | praia da vitoria
# Processing Record 45 of Set 1 | margate
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | san patricio
# Processing Record 51 of Set 2 | paamiut
# Processing Record 52 of Set 2 | metro
# Processing Record 53 of Set 2 | umzimvubu
# CIty not found. Skipping ...
# Processing Record 54 of Set 2 | klichka
# Processing Record 55 of Set 2 | havoysund
# Processing Record 56 of Set 2 | brae
# Processing Record 57 of Set 2 | bambous virieux
# Processing Record 58 of Set 2 | araouane
# Processing Record 59 of Set 2 | srednekolymsk
# Processing Record 60 of Set 2 | busselton
# Processing Record 61 of Set 2 | longyearbyen
# Processing Record 62 of Set 2 | causapscal
# Processing Record 63 of Set 2 | cidreira
# Processing Record 64 of Set 2 | tiksi
# Processing Record 65 of Set 2 | vaini
# Processing Record 66 of Set 2 | bluff
# Processing Record 67 of Set 2 | mendi
# Processing Record 68 of Set 2 | butaritari
# Processing Record 69 of Set 2 | port-gentil
# Processing Record 70 of Set 2 | taksimo
# Processing Record 71 of Set 2 | ancud
# Processing Record 72 of Set 2 | monrovia
# Processing Record 73 of Set 2 | brewster
# Processing Record 74 of Set 2 | viedma
# Processing Record 75 of Set 2 | yellowknife
# Processing Record 76 of Set 2 | tasiilaq
# Processing Record 77 of Set 2 | auki
# Processing Record 78 of Set 2 | ushuaia
# Processing Record 79 of Set 2 | sokoni
# Processing Record 80 of Set 2 | sao filipe
# Processing Record 81 of Set 2 | yushala
# Processing Record 82 of Set 2 | ravar
# Processing Record 83 of Set 2 | saint george
# Processing Record 84 of Set 2 | hilo
# Processing Record 85 of Set 2 | tuktoyaktuk
# Processing Record 86 of Set 2 | atambua
# Processing Record 87 of Set 2 | cape town
# Processing Record 88 of Set 2 | nizhnyaya omka
# Processing Record 89 of Set 2 | whitehorse
# Processing Record 90 of Set 2 | arman
# Processing Record 91 of Set 2 | lorengau
# Processing Record 92 of Set 2 | cabo san lucas
# Processing Record 93 of Set 2 | dunedin
# Processing Record 94 of Set 2 | hermanus
# Processing Record 95 of Set 2 | kavaratti
# Processing Record 96 of Set 2 | khandbari
# Processing Record 97 of Set 2 | hobyo
# Processing Record 98 of Set 2 | willmar
# Processing Record 99 of Set 2 | kavieng
# Processing Record 100 of Set 2 | luderitz
# Processing Record 101 of Set 3 | lasa
# Processing Record 102 of Set 3 | adelaide
# Processing Record 103 of Set 3 | sao joao da barra
# Processing Record 104 of Set 3 | dikson
# Processing Record 105 of Set 3 | castro
# Processing Record 106 of Set 3 | asilah
# Processing Record 107 of Set 3 | nome
# Processing Record 108 of Set 3 | nizhneyansk
# CIty not found. Skipping ...
# Processing Record 109 of Set 3 | kampot
# Processing Record 110 of Set 3 | ponta do sol
# Processing Record 111 of Set 3 | mys shmidta
# CIty not found. Skipping ...
# Processing Record 112 of Set 3 | moree
# Processing Record 113 of Set 3 | chokurdakh
# Processing Record 114 of Set 3 | port blair
# Processing Record 115 of Set 3 | peleduy
# Processing Record 116 of Set 3 | broome
# Processing Record 117 of Set 3 | lebu
# Processing Record 118 of Set 3 | saskylakh
# Processing Record 119 of Set 3 | illoqqortoormiut
# CIty not found. Skipping ...
# Processing Record 120 of Set 3 | ajdabiya
# Processing Record 121 of Set 3 | eureka
# Processing Record 122 of Set 3 | lagoa
# Processing Record 123 of Set 3 | rehoboth
# Processing Record 124 of Set 3 | iqaluit
# Processing Record 125 of Set 3 | waingapu
# Processing Record 126 of Set 3 | caravelas
# Processing Record 127 of Set 3 | nanortalik
# Processing Record 128 of Set 3 | mar del plata
# Processing Record 129 of Set 3 | bredasdorp
# Processing Record 130 of Set 3 | sept-iles
# Processing Record 131 of Set 3 | mahon
# Processing Record 132 of Set 3 | hobart
# Processing Record 133 of Set 3 | binga
# Processing Record 134 of Set 3 | pangody
# Processing Record 135 of Set 3 | tsihombe
# CIty not found. Skipping ...
# Processing Record 136 of Set 3 | trat
# Processing Record 137 of Set 3 | east london
# Processing Record 138 of Set 3 | saint-philippe
# Processing Record 139 of Set 3 | sumbawa
# CIty not found. Skipping ...
# Processing Record 140 of Set 3 | beringovskiy
# Processing Record 141 of Set 3 | airai
# Processing Record 142 of Set 3 | orzhytsya
# Processing Record 143 of Set 3 | kruisfontein
# Processing Record 144 of Set 3 | hithadhoo
# Processing Record 145 of Set 3 | thompson
# Processing Record 146 of Set 3 | tidore
# CIty not found. Skipping ...
# Processing Record 147 of Set 3 | bonavista
# Processing Record 148 of Set 3 | lalsk
# Processing Record 149 of Set 3 | avarua
# Processing Record 150 of Set 3 | vryheid
# Processing Record 151 of Set 4 | haines junction
# Processing Record 152 of Set 4 | marawi
# Processing Record 153 of Set 4 | umm bab
# Processing Record 154 of Set 4 | forrest city
# Processing Record 155 of Set 4 | hailar
# Processing Record 156 of Set 4 | premia de mar
# Processing Record 157 of Set 4 | torbay
# Processing Record 158 of Set 4 | olinda
# Processing Record 159 of Set 4 | mazagao
# Processing Record 160 of Set 4 | praya
# Processing Record 161 of Set 4 | pevek
# Processing Record 162 of Set 4 | gold coast
# Processing Record 163 of Set 4 | liverpool
# Processing Record 164 of Set 4 | ilulissat
# Processing Record 165 of Set 4 | cherskiy
# Processing Record 166 of Set 4 | lahat
# Processing Record 167 of Set 4 | changli
# Processing Record 168 of Set 4 | kendari
# Processing Record 169 of Set 4 | samarai
# Processing Record 170 of Set 4 | adoni
# Processing Record 171 of Set 4 | galgani
# CIty not found. Skipping ...
# Processing Record 172 of Set 4 | fort nelson
# Processing Record 173 of Set 4 | naze
# Processing Record 174 of Set 4 | vao
# Processing Record 175 of Set 4 | acarau
# Processing Record 176 of Set 4 | thayetmyo
# Processing Record 177 of Set 4 | ternate
# Processing Record 178 of Set 4 | barentsburg
# CIty not found. Skipping ...
# Processing Record 179 of Set 4 | severo-kurilsk
# Processing Record 180 of Set 4 | rapid valley
# Processing Record 181 of Set 4 | grand gaube
# Processing Record 182 of Set 4 | ostrovnoy
# Processing Record 183 of Set 4 | lompoc
# Processing Record 184 of Set 4 | cape coast
# Processing Record 185 of Set 4 | pio xii
# Processing Record 186 of Set 4 | rio grande
# Processing Record 187 of Set 4 | qaanaaq
# Processing Record 188 of Set 4 | sitka
# Processing Record 189 of Set 4 | inzhavino
# Processing Record 190 of Set 4 | omboue
# Processing Record 191 of Set 4 | kahului
# Processing Record 192 of Set 4 | leningradskiy
# Processing Record 193 of Set 4 | kaohsiung
# Processing Record 194 of Set 4 | jeremoabo
# Processing Record 195 of Set 4 | axim
# Processing Record 196 of Set 4 | tautira
# Processing Record 197 of Set 4 | hamilton
# Processing Record 198 of Set 4 | tazovskiy
# Processing Record 199 of Set 4 | houma
# Processing Record 200 of Set 4 | shimoda
# Processing Record 201 of Set 5 | alamos
# Processing Record 202 of Set 5 | talcahuano
# Processing Record 203 of Set 5 | manjacaze
# Processing Record 204 of Set 5 | portree
# Processing Record 205 of Set 5 | abalak
# Processing Record 206 of Set 5 | mana
# Processing Record 207 of Set 5 | huarmey
# Processing Record 208 of Set 5 | saldanha
# Processing Record 209 of Set 5 | grindavik
# Processing Record 210 of Set 5 | mozarlandia
# Processing Record 211 of Set 5 | rutana
# Processing Record 212 of Set 5 | gafanha da encarnacao
# Processing Record 213 of Set 5 | scarborough
# Processing Record 214 of Set 5 | marzuq
# Processing Record 215 of Set 5 | marondera
# Processing Record 216 of Set 5 | kondinskoye
# Processing Record 217 of Set 5 | milkovo
# Processing Record 218 of Set 5 | san miguel
# Processing Record 219 of Set 5 | labrea
# Processing Record 220 of Set 5 | palmer
# Processing Record 221 of Set 5 | clyde river
# Processing Record 222 of Set 5 | buala
# Processing Record 223 of Set 5 | urengoy
# Processing Record 224 of Set 5 | itaqui
# Processing Record 225 of Set 5 | souillac
# Processing Record 226 of Set 5 | prainha
# Processing Record 227 of Set 5 | vikhorevka
# Processing Record 228 of Set 5 | lodja
# Processing Record 229 of Set 5 | kristiansund
# Processing Record 230 of Set 5 | new bern
# Processing Record 231 of Set 5 | baker city
# Processing Record 232 of Set 5 | rozivka
# Processing Record 233 of Set 5 | makasar
# Processing Record 234 of Set 5 | vila velha
# Processing Record 235 of Set 5 | ust-kamchatsk
# CIty not found. Skipping ...
# Processing Record 236 of Set 5 | katsuura
# Processing Record 237 of Set 5 | narsaq
# Processing Record 238 of Set 5 | sur
# Processing Record 239 of Set 5 | vincennes
# Processing Record 240 of Set 5 | mubende
# Processing Record 241 of Set 5 | narva-joesuu
# Processing Record 242 of Set 5 | tutoia
# Processing Record 243 of Set 5 | ponta delgada
# Processing Record 244 of Set 5 | trujillo alto
# Processing Record 245 of Set 5 | port augusta
# Processing Record 246 of Set 5 | finschhafen
# Processing Record 247 of Set 5 | cururupu
# Processing Record 248 of Set 5 | strezhevoy
# Processing Record 249 of Set 5 | barrow
# Processing Record 250 of Set 5 | yerbogachen
# Processing Record 251 of Set 6 | isangel
# Processing Record 252 of Set 6 | shelburne
# Processing Record 253 of Set 6 | arraial do cabo
# Processing Record 254 of Set 6 | evensk
# Processing Record 255 of Set 6 | nioro
# Processing Record 256 of Set 6 | taremskoye
# Processing Record 257 of Set 6 | sovetskiy
# Processing Record 258 of Set 6 | kokopo
# Processing Record 259 of Set 6 | florida
# Processing Record 260 of Set 6 | baracoa
# Processing Record 261 of Set 6 | auch
# Processing Record 262 of Set 6 | presidencia roque saenz pena
# Processing Record 263 of Set 6 | nantucket
# Processing Record 264 of Set 6 | coruripe
# Processing Record 265 of Set 6 | kuminskiy
# Processing Record 266 of Set 6 | pekan
# Processing Record 267 of Set 6 | bindi
# Processing Record 268 of Set 6 | kaitangata
# Processing Record 269 of Set 6 | upernavik
# Processing Record 270 of Set 6 | raudeberg
# Processing Record 271 of Set 6 | alta floresta
# Processing Record 272 of Set 6 | namibe
# Processing Record 273 of Set 6 | te anau
# Processing Record 274 of Set 6 | porvoo
# Processing Record 275 of Set 6 | burica
# CIty not found. Skipping ...
# Processing Record 276 of Set 6 | camocim
# Processing Record 277 of Set 6 | samusu
# CIty not found. Skipping ...
# Processing Record 278 of Set 6 | tevaitoa
# Processing Record 279 of Set 6 | lisala
# Processing Record 280 of Set 6 | honningsvag
# Processing Record 281 of Set 6 | oktyabrskiy
# Processing Record 282 of Set 6 | ziniare
# Processing Record 283 of Set 6 | halalo
# CIty not found. Skipping ...
# Processing Record 284 of Set 6 | grand river south east
# CIty not found. Skipping ...
# Processing Record 285 of Set 6 | labuhan
# Processing Record 286 of Set 6 | nuevo progreso
# Processing Record 287 of Set 6 | moscow
# Processing Record 288 of Set 6 | makakilo city
# Processing Record 289 of Set 6 | mukerian
# Processing Record 290 of Set 6 | toliary
# CIty not found. Skipping ...
# Processing Record 291 of Set 6 | ambilobe
# Processing Record 292 of Set 6 | pisco
# Processing Record 293 of Set 6 | fairbanks
# Processing Record 294 of Set 6 | road town
# Processing Record 295 of Set 6 | qandala
# Processing Record 296 of Set 6 | vestmannaeyjar
# Processing Record 297 of Set 6 | provideniya
# Processing Record 298 of Set 6 | tuatapere
# Processing Record 299 of Set 6 | alofi
# Processing Record 300 of Set 6 | buin
# Processing Record 301 of Set 7 | danjiangkou
# Processing Record 302 of Set 7 | sisimiut
# Processing Record 303 of Set 7 | tumannyy
# CIty not found. Skipping ...
# Processing Record 304 of Set 7 | luoyang
# Processing Record 305 of Set 7 | saalfeld
# Processing Record 306 of Set 7 | emerald
# Processing Record 307 of Set 7 | mollendo
# Processing Record 308 of Set 7 | chom bung
# CIty not found. Skipping ...
# Processing Record 309 of Set 7 | karaul
# CIty not found. Skipping ...
# Processing Record 310 of Set 7 | port macquarie
# Processing Record 311 of Set 7 | pavlivka
# Processing Record 312 of Set 7 | anjiang
# Processing Record 313 of Set 7 | menongue
# Processing Record 314 of Set 7 | saint-leu
# Processing Record 315 of Set 7 | portland
# Processing Record 316 of Set 7 | goderich
# Processing Record 317 of Set 7 | avesta
# Processing Record 318 of Set 7 | gigmoto
# Processing Record 319 of Set 7 | sabanagrande
# Processing Record 320 of Set 7 | ouadda
# Processing Record 321 of Set 7 | mineiros
# Processing Record 322 of Set 7 | bengkulu
# Processing Record 323 of Set 7 | kristiinankaupunki
# Processing Record 324 of Set 7 | fairlie
# Processing Record 325 of Set 7 | nizhneivkino
# Processing Record 326 of Set 7 | seymchan
# Processing Record 327 of Set 7 | batagay-alyta
# Processing Record 328 of Set 7 | chuy
# Processing Record 329 of Set 7 | krasnyy kholm
# Processing Record 330 of Set 7 | guarapari
# Processing Record 331 of Set 7 | ardmore
# Processing Record 332 of Set 7 | belyy yar
# Processing Record 333 of Set 7 | sorland
# Processing Record 334 of Set 7 | geraldton
# Processing Record 335 of Set 7 | hasaki
# Processing Record 336 of Set 7 | naron
# Processing Record 337 of Set 7 | burnie
# Processing Record 338 of Set 7 | luanda
# Processing Record 339 of Set 7 | kulhudhuffushi
# Processing Record 340 of Set 7 | general artigas
# Processing Record 341 of Set 7 | tokur
# Processing Record 342 of Set 7 | north bend
# Processing Record 343 of Set 7 | hovd
# Processing Record 344 of Set 7 | zhigansk
# Processing Record 345 of Set 7 | port hardy
# Processing Record 346 of Set 7 | filadelfia
# Processing Record 347 of Set 7 | atar
# Processing Record 348 of Set 7 | taburi
# CIty not found. Skipping ...
# Processing Record 349 of Set 7 | curug
# Processing Record 350 of Set 7 | onguday
# Processing Record 351 of Set 8 | cagayan de tawi-tawi
# CIty not found. Skipping ...
# Processing Record 352 of Set 8 | inta
# Processing Record 353 of Set 8 | nidzica
# Processing Record 354 of Set 8 | guerrero negro
# Processing Record 355 of Set 8 | svetlaya
# Processing Record 356 of Set 8 | yabrud
# Processing Record 357 of Set 8 | ystad
# Processing Record 358 of Set 8 | hun
# Processing Record 359 of Set 8 | nha trang
# Processing Record 360 of Set 8 | nguiu
# CIty not found. Skipping ...
# Processing Record 361 of Set 8 | hualmay
# Processing Record 362 of Set 8 | camacha
# Processing Record 363 of Set 8 | kaputa
# Processing Record 364 of Set 8 | wardenburg
# Processing Record 365 of Set 8 | zambezi
# Processing Record 366 of Set 8 | puerto escondido
# Processing Record 367 of Set 8 | tura
# Processing Record 368 of Set 8 | boa vista
# Processing Record 369 of Set 8 | haapiti
# Processing Record 370 of Set 8 | ambulu
# Processing Record 371 of Set 8 | tessalit
# Processing Record 372 of Set 8 | talnakh
# Processing Record 373 of Set 8 | oranjestad
# Processing Record 374 of Set 8 | kpagouda
# CIty not found. Skipping ...
# Processing Record 375 of Set 8 | vila franca do campo
# Processing Record 376 of Set 8 | levelland
# Processing Record 377 of Set 8 | henties bay
# Processing Record 378 of Set 8 | les cayes
# Processing Record 379 of Set 8 | hambantota
# Processing Record 380 of Set 8 | dubbo
# Processing Record 381 of Set 8 | san-pedro
# Processing Record 382 of Set 8 | najran
# Processing Record 383 of Set 8 | penzance
# Processing Record 384 of Set 8 | hit
# Processing Record 385 of Set 8 | bukama
# Processing Record 386 of Set 8 | dali
# Processing Record 387 of Set 8 | aleksandrov gay
# Processing Record 388 of Set 8 | salalah
# Processing Record 389 of Set 8 | guangyuan
# Processing Record 390 of Set 8 | rusape
# Processing Record 391 of Set 8 | bundaberg
# Processing Record 392 of Set 8 | prince rupert
# Processing Record 393 of Set 8 | svetlogorsk
# Processing Record 394 of Set 8 | south sioux city
# Processing Record 395 of Set 8 | doka
# Processing Record 396 of Set 8 | gimli
# Processing Record 397 of Set 8 | bur gabo
# CIty not found. Skipping ...
# Processing Record 398 of Set 8 | bulawayo
# Processing Record 399 of Set 8 | linxia
# Processing Record 400 of Set 8 | yulara
# Processing Record 401 of Set 9 | san pedro
# Processing Record 402 of Set 9 | belushya guba
# CIty not found. Skipping ...
# Processing Record 403 of Set 9 | bonfim
# Processing Record 404 of Set 9 | klaksvik
# Processing Record 405 of Set 9 | usinsk
# Processing Record 406 of Set 9 | kashi
# Processing Record 407 of Set 9 | mgandu
# Processing Record 408 of Set 9 | tukrah
# Processing Record 409 of Set 9 | port hueneme
# Processing Record 410 of Set 9 | lingao
# Processing Record 411 of Set 9 | nikolsk
# Processing Record 412 of Set 9 | santa rosalia
# Processing Record 413 of Set 9 | channel-port aux basques
# Processing Record 414 of Set 9 | krasnooktyabrskiy
# Processing Record 415 of Set 9 | flinders
# Processing Record 416 of Set 9 | olavarria
# Processing Record 417 of Set 9 | boende
# Processing Record 418 of Set 9 | jalu
# Processing Record 419 of Set 9 | agadir
# Processing Record 420 of Set 9 | brigantine
# Processing Record 421 of Set 9 | san cristobal
# Processing Record 422 of Set 9 | ixtapa
# Processing Record 423 of Set 9 | ormara
# Processing Record 424 of Set 9 | asmara
# Processing Record 425 of Set 9 | matagami
# Processing Record 426 of Set 9 | hofn
# Processing Record 427 of Set 9 | zavyalovo
# Processing Record 428 of Set 9 | keti bandar
# Processing Record 429 of Set 9 | bolitoc
# Processing Record 430 of Set 9 | frolovo
# Processing Record 431 of Set 9 | victoria
# Processing Record 432 of Set 9 | necochea
# Processing Record 433 of Set 9 | san quintin
# Processing Record 434 of Set 9 | beyneu
# Processing Record 435 of Set 9 | kunda
# Processing Record 436 of Set 9 | frontera
# Processing Record 437 of Set 9 | tirumullaivasal
# Processing Record 438 of Set 9 | marcona
# CIty not found. Skipping ...
# Processing Record 439 of Set 9 | acapulco
# Processing Record 440 of Set 9 | atherton
# Processing Record 441 of Set 9 | marsabit
# Processing Record 442 of Set 9 | broceni
# Processing Record 443 of Set 9 | meyungs
# CIty not found. Skipping ...
# Processing Record 444 of Set 9 | arona
# Processing Record 445 of Set 9 | lakki marwat
# Processing Record 446 of Set 9 | kurunegala
# Processing Record 447 of Set 9 | oranjemund
# Processing Record 448 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 449 of Set 9 | simbahan
# Processing Record 450 of Set 9 | karlskoga
# Processing Record 451 of Set 10 | makhachkala
# Processing Record 452 of Set 10 | micheweni
# Processing Record 453 of Set 10 | iberia
# Processing Record 454 of Set 10 | arcachon
# Processing Record 455 of Set 10 | vaitupu
# CIty not found. Skipping ...
# Processing Record 456 of Set 10 | ampanihy
# Processing Record 457 of Set 10 | palaiokhora
# CIty not found. Skipping ...
# Processing Record 458 of Set 10 | port-cartier
# Processing Record 459 of Set 10 | pictou
# Processing Record 460 of Set 10 | gorno-chuyskiy
# CIty not found. Skipping ...
# Processing Record 461 of Set 10 | chagda
# CIty not found. Skipping ...
# Processing Record 462 of Set 10 | ngaoundere
# Processing Record 463 of Set 10 | lubao
# Processing Record 464 of Set 10 | shieli
# Processing Record 465 of Set 10 | punta alta
# Processing Record 466 of Set 10 | bilibino
# Processing Record 467 of Set 10 | adeje
# Processing Record 468 of Set 10 | westport
# Processing Record 469 of Set 10 | faya
# Processing Record 470 of Set 10 | mosetse
# Processing Record 471 of Set 10 | kimberley
# Processing Record 472 of Set 10 | san lorenzo
# Processing Record 473 of Set 10 | lincoln
# Processing Record 474 of Set 10 | velsk
# Processing Record 475 of Set 10 | viking
# Processing Record 476 of Set 10 | sola
# Processing Record 477 of Set 10 | falmouth
# Processing Record 478 of Set 10 | mitsamiouli
# Processing Record 479 of Set 10 | namatanai
# Processing Record 480 of Set 10 | sarangani
# Processing Record 481 of Set 10 | manjeshwar
# Processing Record 482 of Set 10 | pemangkat
# Processing Record 483 of Set 10 | riberalta
# Processing Record 484 of Set 10 | lyngseidet
# Processing Record 485 of Set 10 | bolshaya chernigovka
# CIty not found. Skipping ...
# Processing Record 486 of Set 10 | autun
# Processing Record 487 of Set 10 | karatsu
# Processing Record 488 of Set 10 | takoradi
# Processing Record 489 of Set 10 | krasnoselkup
# Processing Record 490 of Set 10 | guarda
# Processing Record 491 of Set 10 | nabire
# Processing Record 492 of Set 10 | pachino
# Processing Record 493 of Set 10 | fortuna
# Processing Record 494 of Set 10 | esmeraldas
# Processing Record 495 of Set 10 | santa isabel do rio negro
# Processing Record 496 of Set 10 | xiaoweizhai
# Processing Record 497 of Set 10 | illapel
# Processing Record 498 of Set 10 | lianzhou
# Processing Record 499 of Set 10 | elixir
# Processing Record 500 of Set 10 | ferme-neuve
# Processing Record 501 of Set 11 | touros
# Processing Record 502 of Set 11 | viligili
# CIty not found. Skipping ...
# Processing Record 503 of Set 11 | buturlinovka
# Processing Record 504 of Set 11 | lata
# Processing Record 505 of Set 11 | barawe
# CIty not found. Skipping ...
# Processing Record 506 of Set 11 | russell
# Processing Record 507 of Set 11 | plouzane
# Processing Record 508 of Set 11 | warqla
# CIty not found. Skipping ...
# Processing Record 509 of Set 11 | neuquen
# Processing Record 510 of Set 11 | kansk
# Processing Record 511 of Set 11 | opuwo
# Processing Record 512 of Set 11 | beisfjord
# Processing Record 513 of Set 11 | san vicente
# Processing Record 514 of Set 11 | igrim
# Processing Record 515 of Set 11 | bollnas
# Processing Record 516 of Set 11 | santa vitoria do palmar
# Processing Record 517 of Set 11 | lahij
# Processing Record 518 of Set 11 | daura
# Processing Record 519 of Set 11 | attawapiskat
# CIty not found. Skipping ...
# Processing Record 520 of Set 11 | capao da canoa
# Processing Record 521 of Set 11 | laguna
# Processing Record 522 of Set 11 | cayenne
# Processing Record 523 of Set 11 | altar
# Processing Record 524 of Set 11 | booue
# Processing Record 525 of Set 11 | palabuhanratu
# CIty not found. Skipping ...
# Processing Record 526 of Set 11 | kapit
# Processing Record 527 of Set 11 | ucluelet
# Processing Record 528 of Set 11 | laguna de perlas
# Processing Record 529 of Set 11 | surt
# Processing Record 530 of Set 11 | bajil
# Processing Record 531 of Set 11 | likasi
# Processing Record 532 of Set 11 | trairi
# Processing Record 533 of Set 11 | cockburn town
# Processing Record 534 of Set 11 | soyo
# Processing Record 535 of Set 11 | ust-tsilma
# Processing Record 536 of Set 11 | yar-sale
# Processing Record 537 of Set 11 | chongqing
# Processing Record 538 of Set 11 | banda aceh
# Processing Record 539 of Set 11 | beni
# Processing Record 540 of Set 11 | sapao
# CIty not found. Skipping ...
# Processing Record 541 of Set 11 | bowen
# Processing Record 542 of Set 11 | husavik
# Processing Record 543 of Set 11 | puerto del rosario
# Processing Record 544 of Set 11 | bandarbeyla
# Processing Record 545 of Set 11 | boguchany
# Processing Record 546 of Set 11 | boden
# Processing Record 547 of Set 11 | marrakesh
# Processing Record 548 of Set 11 | ishigaki
# Processing Record 549 of Set 11 | preobrazheniye
# Processing Record 550 of Set 11 | tehuantepec
# CIty not found. Skipping ...
# Processing Record 551 of Set 12 | ust-maya
# Processing Record 552 of Set 12 | port hedland
# Processing Record 553 of Set 12 | luganville
# Processing Record 554 of Set 12 | sayaxche
# Processing Record 555 of Set 12 | deer lake
# Processing Record 556 of Set 12 | college
# Processing Record 557 of Set 12 | kununurra
# Processing Record 558 of Set 12 | constitucion
# Processing Record 559 of Set 12 | meulaboh
# Processing Record 560 of Set 12 | vangaindrano
# Processing Record 561 of Set 12 | manokwari
# Processing Record 562 of Set 12 | pontes e lacerda
# Processing Record 563 of Set 12 | itamaraca
# Processing Record 564 of Set 12 | guajara-mirim
# CIty not found. Skipping ...
# Processing Record 565 of Set 12 | uvat
# Processing Record 566 of Set 12 | guozhen
# Processing Record 567 of Set 12 | sakakah
# Processing Record 568 of Set 12 | port keats
# Processing Record 569 of Set 12 | caborca
# Processing Record 570 of Set 12 | olafsvik
# Processing Record 571 of Set 12 | hirtshals
# Processing Record 572 of Set 12 | gizo
# Processing Record 573 of Set 12 | koscierzyna
# Processing Record 574 of Set 12 | dobryanka
# Processing Record 575 of Set 12 | saint-michel-des-saints
# Processing Record 576 of Set 12 | taber
# Processing Record 577 of Set 12 | tecoanapa
# Processing Record 578 of Set 12 | lotofaga
# Processing Record 579 of Set 12 | pangkalanbuun
# Processing Record 580 of Set 12 | mayo
# Processing Record 581 of Set 12 | severo-yeniseyskiy
# Processing Record 582 of Set 12 | chara
# Processing Record 583 of Set 12 | pangnirtung
# Processing Record 584 of Set 12 | barabai
# Processing Record 585 of Set 12 | sheltozero
# Processing Record 586 of Set 12 | anadyr
# Processing Record 587 of Set 12 | ozernovskiy
# Processing Record 588 of Set 12 | dubai
# Processing Record 589 of Set 12 | yumen
# Processing Record 590 of Set 12 | sharjah
# Processing Record 591 of Set 12 | rosetta
# Processing Record 592 of Set 12 | tateyama
# Processing Record 593 of Set 12 | champerico
# Processing Record 594 of Set 12 | vostok
# Processing Record 595 of Set 12 | wilmington
# Processing Record 596 of Set 12 | vanderhoof
# Processing Record 597 of Set 12 | porto de moz
# Processing Record 598 of Set 12 | nouadhibou
# Processing Record 599 of Set 12 | salym
# Processing Record 600 of Set 12 | saleaula
# CIty not found. Skipping ...
# Processing Record 601 of Set 13 | puerto penasco
# Processing Record 602 of Set 13 | poltava
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 557

# %%
#Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Salinas  36.6777 -121.6555     62.69        82         100
# 1  Russkaya Polyana  49.4170   31.9201     75.51        39          55
# 2      Port Lincoln -34.7333  135.8667     55.22        84          93
# 3           Rikitea -23.1203 -134.9692     71.87        76         100
# 4         Esperance -33.8667  121.9000     52.21        60         100
# 5          Kargopol  61.5071   38.9456     67.57        67          37
# 6           Aklavik  68.2191 -135.0107     46.40       100         100
# 7             Acari -15.4311  -74.6158     75.36        47          62
# 8            Albany  42.6001  -73.9662     77.72        75           2
# 9      Puerto Ayora  -0.7393  -90.3518     76.96        83          97
#
#    Wind Speed Country                 Date
# 0        4.61      US  2022-08-28 16:31:45
# 1        4.14      UA  2022-08-28 16:32:14
# 2       12.50      AU  2022-08-28 16:30:45
# 3       24.38      PF  2022-08-28 16:32:14
# 4        9.86      AU  2022-08-28 16:27:44
# 5        3.29      RU  2022-08-28 16:32:15
# 6        9.22      CA  2022-08-28 16:32:15
# 7        9.84      PE  2022-08-28 16:32:15
# 8        4.00      US  2022-08-28 16:27:53
# 9        5.01      EC  2022-08-28 16:32:16

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
#Create the output file (CSV).

output_data_file = "weather_data/cities.csv"

#Export the CIty_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
#Import time module

import time

#Build the scatter plor for latitude vs. max temperature.

plt.scatter(lats,
           max_temps,
           edgecolor= "black", linewidths = 1, marker = "o",
           alpha = 0.8, label = "Cities")

#Incorporate the other graph properties.
plt.title (f"City Latitude vs Max Temperature" + time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure.
plt.savefig("weather_data/Fig1.png")

#Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
#Build the scatter plots for latitude vs Cloudiness

plt.scatter(lats,
           cloudiness,
           edgecolor = "black", linewidths=1, marker = "o",
           alpha = 0.8, label= "Cities")

#Incorporate the other graph properties

plt.title(f"City Latitude vs. Cloudiness (%)" + time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
#Save the figure
plt.savefig("weather_data/Fig3.png")
#Show plot.
plt.show()

# %%
#buld the scatter plots for latitude vs Wind speed

plt.scatter(lats,
           wind_speed,
           edgecolor = "black", linewidths =1, marker = "o",
           alpha = 0.8, label = "Cities")

#incorporate the other graph properties.
plt.title(f"City Latitude vs Wind Speed" + time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

#save the figure
plt.savefig("weather_data/Fig4.png")
#Show the plot
plt.show()
